# %%
import pandas as pd
import os
import plotly
# import plotly.plotly as py
import plotly.graph_objs as go
plotly.offline.init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
files = os.listdir(path='./COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/')

# %%
files[0][-3]
# Out:
# 'c'

# %%
path = './COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/'
csvs = [path+file for file in files if file[-3:]=='csv']

# %%
csvs
# Out:
# ['./COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-26-2020.csv',
#  './COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-27-2020.csv',
#  './COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-18-2020.csv',
#  './COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-19-2020.csv',
#  './COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-10-2020.csv',
#  './COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-11-2020.csv',
#  './COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-12-2020.csv',
#  './COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-13-2020.csv',
#  './COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-07-2020.csv',
#  './COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/03-06-2020.csv',
#  './COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-05-2020.csv',
#  './COVID-19/csse_covid_19_data/csse_covid_19_daily_reports/02-04-2020.csv',
# ...

# %%
dfs = [pd.read_csv(x) for x in csvs]

# %%
dfs[-1]
# Out:
#                            Province/State  Country/Region  \
# 0                                   Hubei  Mainland China
# 1                                     NaN           Italy
# 2                                     NaN     South Korea
# 3                                     NaN            Iran
# 4                               Guangdong  Mainland China
# ..                                    ...             ...
# 250                    Northern Territory       Australia
# 251  Lackland, TX (From Diamond Princess)              US
# 252                 Montgomery County, TX              US
# 253     Omaha, NE (From Diamond Princess)              US
# 254    Travis, CA (From Diamond Princess)              US
#
#              Last Update  Confirmed  Deaths  Recovered  Latitude  Longitude
# 0    2020-03-08T14:43:03      67707    2986      45235   30.9756   112.2707
# 1    2020-03-08T18:03:04       7375     366        622   43.0000    12.0000
# ...

# %%
combined = pd.concat(dfs)
# Out:
# /Users/marshall132/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
combined[(combined['Country/Region']=='US')& (combined['Province/State'].str.contains('NY'))].sort_values(['Last Update'])
# Out:
#      Confirmed Country/Region  Deaths          Last Update  Latitude  \
# 148        1.0             US     0.0  2020-03-02T01:53:03   40.7128
# 136        1.0             US     0.0  2020-03-02T01:53:03   40.7128
# 128        1.0             US     0.0  2020-03-02T01:53:03   40.7128
# 145        1.0             US     0.0  2020-03-03T14:43:03   41.1220
# 74        10.0             US     0.0  2020-03-04T21:23:10   41.1220
# 97         4.0             US     0.0  2020-03-05T21:03:13   40.7128
# 64        18.0             US     0.0  2020-03-05T21:33:03   41.1220
# 159        1.0             US     0.0  2020-03-05T21:43:02   40.7282
# 178        1.0             US     0.0  2020-03-06T14:43:15   40.6546
# 67        19.0             US     0.0  2020-03-06T15:43:03   41.1220
# 74        16.0             US     0.0  2020-03-06T19:13:40   40.7128
# 114        4.0             US     0.0  2020-03-07T00:03:28   40.6546
# 146        2.0             US     0.0  2020-03-07T16:43:02   41.1489
# ...

# %%
def subset_df(country='', region=''):
    return combined[(combined['Country/Region']==country)& (combined['Province/State'].str.contains(region))].sort_values(['Last Update'])

# %%
subset_df(country='US', region='PA')
# Out:
#      Confirmed Country/Region  Deaths          Last Update  Latitude  \
# 187        1.0             US     0.0  2020-03-06T15:33:03   39.9078
# 168        1.0             US     0.0  2020-03-06T15:33:03   39.9078
# 214        1.0             US     0.0  2020-03-06T15:33:03   39.9078
# 201        1.0             US     0.0  2020-03-06T15:33:03   39.9078
# 214        1.0             US     0.0  2020-03-06T16:13:15   41.6739
# 189        1.0             US     0.0  2020-03-06T16:13:15   41.6739
# 255        1.0             US     0.0  2020-03-06T16:13:15   41.6739
# 244        1.0             US     0.0  2020-03-06T16:13:15   41.6739
# 131        4.0             US     0.0  2020-03-08T21:43:03   40.2290
# 124        5.0             US     0.0  2020-03-09T18:33:03   40.2290
#
#      Longitude         Province/State  Recovered
# 187   -75.3879    Delaware County, PA        0.0
# 168   -75.3879    Delaware County, PA        0.0
# 214   -75.3879    Delaware County, PA        0.0
# ...
